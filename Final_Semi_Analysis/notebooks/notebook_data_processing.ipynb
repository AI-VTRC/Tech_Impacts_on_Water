# %% [markdown]
# ### Big data

# %%
import pandas as pd

# Load the dataset
big_data = pd.read_csv('../data/big_data.csv')

# Filter rows where the 'name_0' column is 'United States'
us_data = big_data[big_data['name_0'] == 'United States']

# Display the filtered DataFrame
print(us_data.shape)
us_data.head(5)
# Out:
# (3433, 231)
#                  string_id  aq30_id  pfaf_id    gid_1  aqid gid_0  \
# 29007  355000-USA.2_1-1047    29004   355000  USA.2_1  1047   USA
# 29008  355000-USA.2_1-1064    29005   355000  USA.2_1  1064   USA
# 29009  355000-USA.2_1-1079    29006   355000  USA.2_1  1079   USA
# 29010  355000-USA.2_1-1083    29007   355000  USA.2_1  1083   USA
# 29011  355000-USA.2_1-1085    29008   355000  USA.2_1  1085   USA
#
#               name_0  name_1    area_km2   bws_raw  ...  w_awr_tex_qal_label  \
# 29007  United States  Alaska  781.766461  0.000023  ...            Low (0-1)
# 29008  United States  Alaska  206.480664  0.000023  ...            Low (0-1)
# 29009  United States  Alaska  254.894601  0.000023  ...            Low (0-1)
# 29010  United States  Alaska  216.348231  0.000023  ...            Low (0-1)
# 29011  United States  Alaska   60.852730  0.000023  ...            Low (0-1)
#
#        w_awr_tex_rrr_raw w_awr_tex_rrr_score  w_awr_tex_rrr_cat  \
# 29007           2.183257            2.558632                2.0
# 29008           2.183257            2.558632                2.0
# 29009           2.183257            2.558632                2.0
# 29010           2.183257            2.558632                2.0
# 29011           2.183257            2.558632                2.0
#
#        w_awr_tex_rrr_label  w_awr_tex_tot_raw w_awr_tex_tot_score  \
# 29007  Medium - High (2-3)           1.052511            1.070852
# 29008  Medium - High (2-3)           1.052511            1.070852
# 29009  Medium - High (2-3)           1.052511            1.070852
# 29010  Medium - High (2-3)           1.052511            1.070852
# 29011  Medium - High (2-3)           1.052511            1.070852
#
#        w_awr_tex_tot_cat  w_awr_tex_tot_label  w_awr_tex_tot_weight_fraction
# 29007                1.0   Low - Medium (1-2)                       0.877551
# 29008                1.0   Low - Medium (1-2)                       0.877551
# 29009                1.0   Low - Medium (1-2)                       0.877551
# 29010                1.0   Low - Medium (1-2)                       0.877551
# 29011                1.0   Low - Medium (1-2)                       0.877551
#
# [5 rows x 231 columns]

# %%
# Columns to keep are only those with '_raw' in their names (indicating raw values) and essential identifiers
columns_to_keep = ['string_id', 'aq30_id', 'pfaf_id', 'gid_1', 'aqid', 'gid_0', 'name_0', 'name_1', 'area_km2'] + [col for col in us_data.columns if '_raw' in col and col not in ['ucw_raw', 'rri_raw']] 

# Remove all columns starting with 'w_awr' from the columns to keep
columns_to_keep = [col for col in columns_to_keep if not col.startswith('w_awr')]

# Create a new DataFrame with only the columns we want to keep
cleaned_us_data = us_data[columns_to_keep]

# Display the first few rows of the cleaned DataFrame to verify
print(cleaned_us_data.shape)
cleaned_us_data.head(5)
# Out:
# (3433, 20)
#                  string_id  aq30_id  pfaf_id    gid_1  aqid gid_0  \
# 29007  355000-USA.2_1-1047    29004   355000  USA.2_1  1047   USA
# 29008  355000-USA.2_1-1064    29005   355000  USA.2_1  1064   USA
# 29009  355000-USA.2_1-1079    29006   355000  USA.2_1  1079   USA
# 29010  355000-USA.2_1-1083    29007   355000  USA.2_1  1083   USA
# 29011  355000-USA.2_1-1085    29008   355000  USA.2_1  1085   USA
#
#               name_0  name_1    area_km2   bws_raw   bwd_raw   iav_raw  \
# 29007  United States  Alaska  781.766461  0.000023  0.000009  0.233706
# 29008  United States  Alaska  206.480664  0.000023  0.000009  0.233706
# 29009  United States  Alaska  254.894601  0.000023  0.000009  0.233706
# 29010  United States  Alaska  216.348231  0.000023  0.000009  0.233706
# 29011  United States  Alaska   60.852730  0.000023  0.000009  0.233706
#
#        sev_raw  gtd_raw   rfr_raw  cfr_raw   drr_raw  cep_raw   udw_raw  \
# 29007  0.12846  -9999.0  0.000106      0.0  0.084501  -9999.0  0.081809
# 29008  0.12846  -9999.0  0.000106      0.0  0.084501  -9999.0  0.081809
# 29009  0.12846  -9999.0  0.000106      0.0  0.084501  -9999.0  0.081809
# 29010  0.12846  -9999.0  0.000106      0.0  0.084501  -9999.0  0.081809
# 29011  0.12846  -9999.0  0.000106      0.0  0.084501  -9999.0  0.081809
#
#         usa_raw
# 29007  0.239945
# 29008  0.239945
# 29009  0.239945
# 29010  0.239945
# 29011  0.239945

# %%
# Create a copy of the DataFrame to avoid SettingWithCopyWarning
cleaned_us_data = us_data[columns_to_keep].copy()

# Rename the columns 'name_0' to 'country' and 'name_1' to 'state'
cleaned_us_data.rename(columns={'name_0': 'country', 'name_1': 'state'}, inplace=True)

# Display the first few rows of the DataFrame to verify the new column names
cleaned_us_data.head(3)
# Out:
#                  string_id  aq30_id  pfaf_id    gid_1  aqid gid_0  \
# 29007  355000-USA.2_1-1047    29004   355000  USA.2_1  1047   USA
# 29008  355000-USA.2_1-1064    29005   355000  USA.2_1  1064   USA
# 29009  355000-USA.2_1-1079    29006   355000  USA.2_1  1079   USA
#
#              country   state    area_km2   bws_raw   bwd_raw   iav_raw  \
# 29007  United States  Alaska  781.766461  0.000023  0.000009  0.233706
# 29008  United States  Alaska  206.480664  0.000023  0.000009  0.233706
# 29009  United States  Alaska  254.894601  0.000023  0.000009  0.233706
#
#        sev_raw  gtd_raw   rfr_raw  cfr_raw   drr_raw  cep_raw   udw_raw  \
# 29007  0.12846  -9999.0  0.000106      0.0  0.084501  -9999.0  0.081809
# 29008  0.12846  -9999.0  0.000106      0.0  0.084501  -9999.0  0.081809
# 29009  0.12846  -9999.0  0.000106      0.0  0.084501  -9999.0  0.081809
#
#         usa_raw
# 29007  0.239945
# 29008  0.239945
# 29009  0.239945

# %%
summary_statistics = cleaned_us_data.describe()
summary_statistics
# Out:
#             aq30_id        pfaf_id         aqid      area_km2      bws_raw  \
# count   3433.000000    3433.000000  3433.000000   3433.000000  3433.000000
# mean   56551.759977  736110.127876   290.524323   2760.783880    -2.492050
# std     3349.324802  134629.230632  3019.134111   4290.037442  2714.832512
# min    29004.000000   -9999.000000 -9999.000000      0.004343 -9999.000000
# 25%    54286.000000  742235.000000   844.000000    154.866505     0.002877
# 50%    55173.000000  742984.000000  1216.000000   1116.369341     0.105794
# 75%    58659.000000  774500.000000  1400.000000   3663.893000     0.479139
# max    68407.000000  821004.000000  1898.000000  52985.016508  9999.000000
#
#            bwd_raw      iav_raw      sev_raw      gtd_raw      rfr_raw  \
# count  3433.000000  3433.000000  3433.000000  3433.000000  3433.000000
# mean     -2.676207  -369.350026  -369.497302  -858.903539  -297.084168
# std    2714.832192  1887.661874  1887.632995  2802.841982  1697.983768
# min   -9999.000000 -9999.000000 -9999.000000 -9999.000000 -9999.000000
# 25%       0.000763     0.372785     0.245559    -0.274031     0.000208
# 50%       0.031802     0.522697     0.368724     0.000000     0.000887
# 75%       0.163312     0.695753     0.527417     0.392393     0.002546
# max    9999.000000     5.239926     1.596155    10.717500     0.038593
#
#            cfr_raw      drr_raw      cep_raw      udw_raw      usa_raw
# count  3433.000000  3433.000000  3433.000000  3433.000000  3433.000000
# mean   -297.086383  -684.132825  -339.525438  -297.062304  -297.083922
# std    1697.983380  2525.425902  1806.663274  1697.987595  1697.983811
# min   -9999.000000 -9999.000000 -9999.000000 -9999.000000 -9999.000000
# 25%       0.000000     0.279299    -1.524866     0.018031     0.000714
# 50%       0.000000     0.360642    -0.119384     0.028544     0.001053
# 75%       0.000000     0.426054     0.934831     0.033246     0.001175
# max       0.025227     0.596387    26.891595     0.081809     0.239945

# %%
no_duplicates = cleaned_us_data.drop_duplicates([col for col in cleaned_us_data.columns if '_raw' in col] )
no_duplicates.head(5)
# Out:
#                  string_id  aq30_id  pfaf_id     gid_1  aqid gid_0  \
# 29007  355000-USA.2_1-1047    29004   355000   USA.2_1  1047   USA
# 51881  712243-USA.24_1-352    51880   712243  USA.24_1   352   USA
# 51882  712243-USA.24_1-844    51881   712243  USA.24_1   844   USA
# 51883  712244-USA.24_1-352    51882   712244  USA.24_1   352   USA
# 51884  712244-USA.24_1-844    51883   712244  USA.24_1   844   USA
#
#              country      state     area_km2   bws_raw   bwd_raw   iav_raw  \
# 29007  United States     Alaska   781.766461  0.000023  0.000009  0.233706
# 51881  United States  Minnesota  1358.169040  0.020586  0.004826  0.351838
# 51882  United States  Minnesota  6148.518524  0.020586  0.004826  0.351838
# 51883  United States  Minnesota  2085.358259  0.030276  0.008565  0.534162
# 51884  United States  Minnesota  3287.536309  0.030276  0.008565  0.534162
#
#         sev_raw      gtd_raw   rfr_raw  cfr_raw   drr_raw      cep_raw  \
# 29007  0.128460 -9999.000000  0.000106      0.0  0.084501 -9999.000000
# 51881  0.206946     0.320780  0.005378      0.0  0.299685     0.291538
# 51882  0.206946    -0.430512  0.005378      0.0  0.299685     0.291538
# 51883  0.308120     0.320780  0.005807      0.0  0.482654     0.300363
# 51884  0.308120    -0.430512  0.005807      0.0  0.482654     0.300363
#
#         udw_raw   usa_raw
# 29007  0.081809  0.239945
# 51881  0.015730  0.012060
# 51882  0.015730  0.012060
# 51883  0.033246  0.001175
# 51884  0.033246  0.001175

# %%
certain_value = 'Hawaii'
column_name = 'state'  # Example column name

# Dropping rows with certain_value in column_name
final_us_data  = no_duplicates[no_duplicates[column_name] != certain_value]
#df.head(5)

# %%
final_us_data.shape
# Out:
# (2593, 20)

# %% [markdown]
# ### Small data

# %%
import pandas as pd

# Load the dataset
small_data = pd.read_csv('../data/small_data.csv')

# Display the filtered DataFrame
print(small_data.shape)
small_data.head()
# Out:
# (360, 271)
#                                             the_geom  points_id location_name  \
# 0  0101000020E610000070253B3602EF54C01B649291B322...          0     undefined
# 1  0101000020E61000008811C2A38DC951C0FFEC478AC83C...          1     undefined
# 2  0101000020E6100000E4C8FB1FFD5353C0DC7D12C83A76...          2     undefined
# 3  0101000020E610000093BC001C77A352C04961621CF123...          3     undefined
# 4  0101000020E6100000CAA5F10BAF7B5EC0D7CF8BA8C3BE...          4     undefined
#
#   input_address match_address   latitude   longitude  \
# 0             _             -  42.271105  -83.734510
# 1             _             -  42.474870  -71.149270
# 2             _             -  42.923669  -77.312325
# 3             _             -  40.280796  -74.554145
# 4             _             -  37.490346 -121.932559
#
#                       major_basin_name minor_basin_name aquifer_name  ...  \
# 0                          St Lawrence            Huron          NaN  ...
# 1              Atlantic Ocean Seaboard          Charles          NaN  ...
# 2                          St Lawrence           Seneca          NaN  ...
# 3  United States, North Atlantic Coast          Raritan          NaN  ...
# 4                           California           Coyote          NaN  ...
#
#   w_awr_tex_rrr_raw  w_awr_tex_rrr_score  w_awr_tex_rrr_cat  \
# 0          0.617001             1.290826                  1
# 1          0.461973             1.148599                  1
# 2          0.694777             1.362180                  1
# 3          0.486630             1.171221                  1
# 4          0.440000             1.128440                  1
#
#   w_awr_tex_rrr_label  w_awr_tex_rrr_weight_fraction w_awr_tex_tot_raw  \
# 0  Low - Medium (1-2)                       0.326531          1.168445
# 1  Low - Medium (1-2)                       0.326531          1.101490
# 2  Low - Medium (1-2)                       0.326531          0.760882
# 3  Low - Medium (1-2)                       0.326531          1.191432
# 4  Low - Medium (1-2)                       0.326531          1.265384
#
#   w_awr_tex_tot_score w_awr_tex_tot_cat  w_awr_tex_tot_label  \
# 0            1.264075                 1   Low - Medium (1-2)
# 1            1.152484                 1   Low - Medium (1-2)
# 2            0.753348                 0            Low (0-1)
# 3            1.302387                 1   Low - Medium (1-2)
# 4            1.425640                 1   Low - Medium (1-2)
#
#    w_awr_tex_tot_weight_fraction
# 0                       0.918367
# 1                       0.918367
# 2                       0.918367
# 3                       1.000000
# 4                       0.918367
#
# [5 rows x 271 columns]

# %%
# Define the columns to keep
columns_to_keep = ['string_id', 'aq30_id', 'pfaf_id', 'gid_1', 'aqid', 'gid_0', 'name_0', 'name_1', 'area_km2'] + [col for col in small_data.columns if '_raw' in col and col not in ['ucw_raw', 'rri_raw']] 

# Remove any columns starting with 'w_awr' from the list
columns_to_keep = [col for col in columns_to_keep if not col.startswith('w_awr')]

# Create a new DataFrame with only the specified columns
cleaned_small_data = small_data[columns_to_keep].copy()

# %%
no_duplicates1 = cleaned_small_data.drop_duplicates([col for col in cleaned_small_data.columns if '_raw' in col] )
no_duplicates1.head(5)
# Out:
#               string_id  aq30_id  pfaf_id     gid_1  aqid gid_0  \
# 0   725572-USA.23_1-844    53190   725572  USA.23_1   844   USA
# 1  731190-USA.22_1-1158    53593   731190  USA.22_1  1158   USA
# 2  725540-USA.33_1-1158    53139   725540  USA.33_1  1158   USA
# 3  731504-USA.31_1-1400    53662   731504  USA.31_1  1400   USA
# 4   774300-USA.5_1-1441    58425   774300   USA.5_1  1441   USA
#
#           name_0         name_1      area_km2   bws_raw   bwd_raw   iav_raw  \
# 0  United States       Michigan   2062.767827  0.577778  0.124035  0.322604
# 1  United States  Massachusetts   8235.727113  0.227893  0.056918  0.109970
# 2  United States       New York  13679.987580  0.001699  0.000475  0.372785
# 3  United States     New Jersey   1133.681346  0.733216  0.195625  0.398473
# 4  United States     California  10534.359930  0.168964  0.048209  0.657045
#
#     sev_raw   gtd_raw   rfr_raw   cfr_raw   drr_raw   cep_raw   udw_raw  \
# 0  0.319555 -0.430512  0.001230  0.000000  0.404088  1.850749  0.020419
# 1  0.062591 -0.888467  0.003236  0.000043  0.283779  5.962378  0.013285
# 2  0.388458 -0.888467  0.001266  0.000000  0.333397  1.928940  0.025333
# 3  0.301855  0.602974  0.000191  0.000000  0.344127  7.842522  0.014225
# 4  0.713420 -0.365303  0.007320  0.000049  0.363087  9.124589  0.005542
#
#     usa_raw
# 0  0.000733
# 1  0.000486
# 2  0.000902
# 3  0.000519
# 4  0.000220

# %%
# Display the filtered DataFrame
print(cleaned_small_data.shape)
cleaned_small_data.head()
# Out:
# (360, 20)
#               string_id  aq30_id  pfaf_id     gid_1  aqid gid_0  \
# 0   725572-USA.23_1-844    53190   725572  USA.23_1   844   USA
# 1  731190-USA.22_1-1158    53593   731190  USA.22_1  1158   USA
# 2  725540-USA.33_1-1158    53139   725540  USA.33_1  1158   USA
# 3  731504-USA.31_1-1400    53662   731504  USA.31_1  1400   USA
# 4   774300-USA.5_1-1441    58425   774300   USA.5_1  1441   USA
#
#           name_0         name_1      area_km2   bws_raw   bwd_raw   iav_raw  \
# 0  United States       Michigan   2062.767827  0.577778  0.124035  0.322604
# 1  United States  Massachusetts   8235.727113  0.227893  0.056918  0.109970
# 2  United States       New York  13679.987580  0.001699  0.000475  0.372785
# 3  United States     New Jersey   1133.681346  0.733216  0.195625  0.398473
# 4  United States     California  10534.359930  0.168964  0.048209  0.657045
#
#     sev_raw   gtd_raw   rfr_raw   cfr_raw   drr_raw   cep_raw   udw_raw  \
# 0  0.319555 -0.430512  0.001230  0.000000  0.404088  1.850749  0.020419
# 1  0.062591 -0.888467  0.003236  0.000043  0.283779  5.962378  0.013285
# 2  0.388458 -0.888467  0.001266  0.000000  0.333397  1.928940  0.025333
# 3  0.301855  0.602974  0.000191  0.000000  0.344127  7.842522  0.014225
# 4  0.713420 -0.365303  0.007320  0.000049  0.363087  9.124589  0.005542
#
#     usa_raw
# 0  0.000733
# 1  0.000486
# 2  0.000902
# 3  0.000519
# 4  0.000220

# %%
# Rename the columns 'name_0' to 'country' and 'name_1' to 'state'
cleaned_small_data.rename(columns={'name_0': 'country', 'name_1': 'state'}, inplace=True)

# %%
cleaned_small_data.head(3)
# Out:
#               string_id  aq30_id  pfaf_id     gid_1  aqid gid_0  \
# 0   725572-USA.23_1-844    53190   725572  USA.23_1   844   USA
# 1  731190-USA.22_1-1158    53593   731190  USA.22_1  1158   USA
# 2  725540-USA.33_1-1158    53139   725540  USA.33_1  1158   USA
#
#          country          state      area_km2   bws_raw   bwd_raw   iav_raw  \
# 0  United States       Michigan   2062.767827  0.577778  0.124035  0.322604
# 1  United States  Massachusetts   8235.727113  0.227893  0.056918  0.109970
# 2  United States       New York  13679.987580  0.001699  0.000475  0.372785
#
#     sev_raw   gtd_raw   rfr_raw   cfr_raw   drr_raw   cep_raw   udw_raw  \
# 0  0.319555 -0.430512  0.001230  0.000000  0.404088  1.850749  0.020419
# 1  0.062591 -0.888467  0.003236  0.000043  0.283779  5.962378  0.013285
# 2  0.388458 -0.888467  0.001266  0.000000  0.333397  1.928940  0.025333
#
#     usa_raw
# 0  0.000733
# 1  0.000486
# 2  0.000902

# %% [markdown]
# ### Saving both dataframe in CSV files

# %%
# Save the cleaned large dataset to a CSV file
final_us_data.to_csv('../data/cleaned_large_data.csv', index=False)

# Save the cleaned small dataset to a CSV file
cleaned_small_data.to_csv('../data/cleaned_small_data.csv', index=False)

# %% [markdown]
# ### Load the saved files again and Look for duplicate values

# %%
import pandas as pd

# Assuming you have already loaded your datasets into DataFrame
# Load datasets if not already done
large_data = pd.read_csv('../data/cleaned_large_data.csv')
small_data = pd.read_csv('../data/cleaned_small_data.csv')

# Remove duplicates based on 'aqid' and all other columns
small_data = small_data.drop_duplicates(subset=['aqid'] + list(small_data.columns))
large_data = large_data.drop_duplicates(subset=['aqid'] + list(large_data.columns))

# Save the cleaned datasets
small_data.to_csv('../data/cleaned_small_data.csv', index=False)
large_data.to_csv('../data/cleaned_large_data.csv', index=False)

# %%
large_data
# Out:
#                 string_id  aq30_id  pfaf_id     gid_1  aqid gid_0  \
# 0     355000-USA.2_1-1047    29004   355000   USA.2_1  1047   USA
# 1     712243-USA.24_1-352    51880   712243  USA.24_1   352   USA
# 2     712243-USA.24_1-844    51881   712243  USA.24_1   844   USA
# 3     712244-USA.24_1-352    51882   712244  USA.24_1   352   USA
# 4     712244-USA.24_1-844    51883   712244  USA.24_1   844   USA
# ...                   ...      ...      ...       ...   ...   ...
# 2588   None-USA.44_1-1722    68392    -9999  USA.44_1  1722   USA
# 2589   None-USA.44_1-1758    68393    -9999  USA.44_1  1758   USA
# 2590   None-USA.44_1-1765    68394    -9999  USA.44_1  1765   USA
# 2591   None-USA.48_1-1181    68398    -9999  USA.48_1  1181   USA
# 2592    None-USA.5_1-1441    68401    -9999   USA.5_1  1441   USA
#
#             country       state     area_km2      bws_raw      bwd_raw  \
# 0     United States      Alaska   781.766461     0.000023     0.000009
# 1     United States   Minnesota  1358.169040     0.020586     0.004826
# 2     United States   Minnesota  6148.518524     0.020586     0.004826
# 3     United States   Minnesota  2085.358259     0.030276     0.008565
# 4     United States   Minnesota  3287.536309     0.030276     0.008565
# ...             ...         ...          ...          ...          ...
# 2588  United States       Texas     0.074804 -9999.000000 -9999.000000
# 2589  United States       Texas     0.008340 -9999.000000 -9999.000000
# 2590  United States       Texas     1.091054 -9999.000000 -9999.000000
# 2591  United States  Washington     1.898456 -9999.000000 -9999.000000
# 2592  United States  California     0.057912 -9999.000000 -9999.000000
#
#           iav_raw      sev_raw      gtd_raw      rfr_raw  cfr_raw  \
# 0        0.233706     0.128460 -9999.000000     0.000106      0.0
# 1        0.351838     0.206946     0.320780     0.005378      0.0
# 2        0.351838     0.206946    -0.430512     0.005378      0.0
# 3        0.534162     0.308120     0.320780     0.005807      0.0
# 4        0.534162     0.308120    -0.430512     0.005807      0.0
# ...           ...          ...          ...          ...      ...
# 2588 -9999.000000 -9999.000000     0.188728 -9999.000000  -9999.0
# 2589 -9999.000000 -9999.000000     0.001182 -9999.000000  -9999.0
# 2590 -9999.000000 -9999.000000     0.015472 -9999.000000  -9999.0
# 2591 -9999.000000 -9999.000000     0.022761 -9999.000000  -9999.0
# 2592 -9999.000000 -9999.000000    -0.365303 -9999.000000  -9999.0
#
#           drr_raw      cep_raw      udw_raw      usa_raw
# 0        0.084501 -9999.000000     0.081809     0.239945
# 1        0.299685     0.291538     0.015730     0.012060
# 2        0.299685     0.291538     0.015730     0.012060
# 3        0.482654     0.300363     0.033246     0.001175
# 4        0.482654     0.300363     0.033246     0.001175
# ...           ...          ...          ...          ...
# 2588 -9999.000000 -9999.000000 -9999.000000 -9999.000000
# 2589 -9999.000000 -9999.000000 -9999.000000 -9999.000000
# 2590 -9999.000000 -9999.000000 -9999.000000 -9999.000000
# 2591 -9999.000000 -9999.000000 -9999.000000 -9999.000000
# 2592 -9999.000000 -9999.000000 -9999.000000 -9999.000000
#
# [2593 rows x 20 columns]

# %%
small_data
# Out:
#                 string_id  aq30_id  pfaf_id     gid_1  aqid gid_0  \
# 0     725572-USA.23_1-844    53190   725572  USA.23_1   844   USA
# 1    731190-USA.22_1-1158    53593   731190  USA.22_1  1158   USA
# 2    725540-USA.33_1-1158    53139   725540  USA.33_1  1158   USA
# 3    731504-USA.31_1-1400    53662   731504  USA.31_1  1400   USA
# 4     774300-USA.5_1-1441    58425   774300   USA.5_1  1441   USA
# ..                    ...      ...      ...       ...   ...   ...
# 346  742493-USA.17_1-1363    54397   742493  USA.17_1  1363   USA
# 351  725555-USA.33_1-1158    53156   725555  USA.33_1  1158   USA
# 352  742678-USA.36_1-1216    54575   742678  USA.36_1  1216   USA
# 354  732407-USA.41_1-1414    53888   732407  USA.41_1  1414   USA
# 355  751640-USA.44_1-1612    55189   751640  USA.44_1  1612   USA
#
#            country           state      area_km2   bws_raw   bwd_raw  \
# 0    United States        Michigan   2062.767827  0.577778  0.124035
# 1    United States   Massachusetts   8235.727113  0.227893  0.056918
# 2    United States        New York  13679.987580  0.001699  0.000475
# 3    United States      New Jersey   1133.681346  0.733216  0.195625
# 4    United States      California  10534.359930  0.168964  0.048209
# ..             ...             ...           ...       ...       ...
# 346  United States          Kansas  14058.932370  0.304765  0.149098
# 351  United States        New York   5746.506270  0.005066  0.001206
# 352  United States            Ohio  17080.695270  0.356605  0.084135
# 354  United States  South Carolina    514.146944  0.152156  0.030839
# 355  United States           Texas  13176.612830  0.245373  0.078500
#
#       iav_raw   sev_raw   gtd_raw   rfr_raw   cfr_raw   drr_raw   cep_raw  \
# 0    0.322604  0.319555 -0.430512  0.001230  0.000000  0.404088  1.850749
# 1    0.109970  0.062591 -0.888467  0.003236  0.000043  0.283779  5.962378
# 2    0.372785  0.388458 -0.888467  0.001266  0.000000  0.333397  1.928940
# 3    0.398473  0.301855  0.602974  0.000191  0.000000  0.344127  7.842522
# 4    0.657045  0.713420 -0.365303  0.007320  0.000049  0.363087  9.124589
# ..        ...       ...       ...       ...       ...       ...       ...
# 346  0.755554  0.456868  0.328266  0.002351  0.000000  0.530588  0.934831
# 351  0.367254  0.328150 -0.888467  0.001880  0.000000  0.315653  1.718303
# 352  0.253237  0.207962 -0.274031  0.000126  0.000000  0.501858  0.934937
# 354  0.602346  0.096399  1.070200  0.000015  0.000000  0.376405 -0.320061
# 355  0.595262  0.167992  0.707641  0.001437  0.000000  0.455871 -0.527336
#
#       udw_raw   usa_raw
# 0    0.020419  0.000733
# 1    0.013285  0.000486
# 2    0.025333  0.000902
# 3    0.014225  0.000519
# 4    0.005542  0.000220
# ..        ...       ...
# 346  0.017656  0.000637
# 351  0.013828  0.001975
# 352  0.015105  0.000550
# 354  0.025970  0.000924
# 355  0.017909  0.000646
#
# [98 rows x 20 columns]

# %%
# Ensuring both dataframes have the same columns and in the same order
small_data = small_data.reindex(columns=large_data.columns)

# %%
# Concatenate the DataFrames
merged_data = pd.concat([small_data, large_data], ignore_index=True)

# %%
merged_data.shape
# Out:
# (2691, 20)

# %%
# Adding a 'presence_absence' column
# Assuming 'small_data' has been assigned 1 (With) and 'big_data' 0 (Without)
merged_data['presence_absence'] = [1] * len(small_data) + [0] * len(large_data)

# %%
# Sort the merged data by 'presence_absence' in descending order so that '1' (with) comes before '0' (without)
merged_data.sort_values(by='presence_absence', ascending=False, inplace=True)

# %%
merged_data
# Out:
#                  string_id  aq30_id  pfaf_id     gid_1  aqid gid_0  \
# 0      725572-USA.23_1-844    53190   725572  USA.23_1   844   USA
# 74    732402-USA.41_1-1400    53878   732402  USA.41_1  1400   USA
# 72     774160-USA.5_1-1441    58402   774160   USA.5_1  1441   USA
# 71     781002-USA.38_1-725    58589   781002  USA.38_1   725   USA
# 70    732571-USA.10_1-1400    53938   732571  USA.10_1  1400   USA
# ...                    ...      ...      ...       ...   ...   ...
# 962   742850-USA.16_1-1342    54698   742850  USA.16_1  1342   USA
# 963   742850-USA.16_1-1357    54699   742850  USA.16_1  1357   USA
# 964   742861-USA.16_1-1216    54700   742861  USA.16_1  1216   USA
# 965   742862-USA.16_1-1216    54701   742862  USA.16_1  1216   USA
# 2690     None-USA.5_1-1441    68401    -9999   USA.5_1  1441   USA
#
#             country           state      area_km2      bws_raw  ...  \
# 0     United States        Michigan   2062.767827     0.577778  ...
# 74    United States  South Carolina   1981.427932     0.671913  ...
# 72    United States      California   6489.297197     5.307029  ...
# 71    United States          Oregon   9329.110744     0.063482  ...
# 70    United States         Florida   9542.228009     0.694238  ...
# ...             ...             ...           ...          ...  ...
# 962   United States            Iowa   3020.236135     0.034949  ...
# 963   United States            Iowa      0.039441     0.034949  ...
# 964   United States            Iowa    984.954139     0.001900  ...
# 965   United States            Iowa  11438.178907     0.350007  ...
# 2690  United States      California      0.057912 -9999.000000  ...
#
#           iav_raw      sev_raw   gtd_raw      rfr_raw      cfr_raw  \
# 0        0.322604     0.319555 -0.430512     0.001230     0.000000
# 74       0.474361     0.170584  0.602974     0.000790     0.000000
# 72       0.723832     0.501935 -0.365303     0.000961     0.000000
# 71       0.387921     0.501520 -0.027497     0.001441     0.000000
# 70       0.581573     0.441926  0.602974     0.007218     0.000013
# ...           ...          ...       ...          ...          ...
# 962      0.602831     0.491119  0.392393     0.000290     0.000000
# 963      0.602831     0.491119  0.299090     0.000290     0.000000
# 964      0.603460     0.504561 -0.274031     0.000712     0.000000
# 965      0.977279     0.524131 -0.274031     0.000424     0.000000
# 2690 -9999.000000 -9999.000000 -0.365303 -9999.000000 -9999.000000
#
#           drr_raw      cep_raw      udw_raw      usa_raw  presence_absence
# 0        0.404088     1.850749     0.020419     0.000733                 1
# 74       0.367905    -0.261415     0.024722     0.000881                 1
# 72       0.366932     3.497037     0.005112     0.000205                 1
# 71       0.294180   -18.101568     0.019064     0.000686                 1
# 70       0.315998    -9.788635     0.005696     0.000225                 1
# ...           ...          ...          ...          ...               ...
# 962      0.575922     0.934831     0.025940     0.000923                 0
# 963      0.575922     0.934831     0.025940     0.000923                 0
# 964      0.569525     0.934831     0.033246     0.001175                 0
# 965      0.579359     0.934831     0.025209     0.000898                 0
# 2690 -9999.000000 -9999.000000 -9999.000000 -9999.000000                 0
#
# [2691 rows x 21 columns]

# %%
# Drop duplicates based on all columns except 'presence_absence'
merged_data.drop_duplicates(subset=merged_data.columns.difference(['presence_absence']), keep='first', inplace=True)

# %%
# Define the columns of interest
columns_of_interest = [col for col in merged_data.columns if '_raw' in col] 

# Calculate the percentage of rows that are zero for each specified column
zero_counts_percentage = {col: (merged_data[col] == 0).mean() * 100 for col in columns_of_interest}
zero_counts_percentage
# Out:
# {'bws_raw': 1.0405053883314752,
#  'bwd_raw': 1.0776662950575995,
#  'iav_raw': 0.0,
#  'sev_raw': 0.0,
#  'gtd_raw': 0.5202526941657376,
#  'rfr_raw': 10.962467484206615,
#  'cfr_raw': 84.72686733556299,
#  'drr_raw': 0.0,
#  'cep_raw': 0.14864362690449648,
#  'udw_raw': 8.621330360460796,
#  'usa_raw': 8.621330360460796}

# %%
# Remove columns with more than 30% zeros
merged_data.drop(columns=['cfr_raw'], inplace=True)
merged_data.head(5)
# Out:
#                string_id  aq30_id  pfaf_id     gid_1  aqid gid_0  \
# 0    725572-USA.23_1-844    53190   725572  USA.23_1   844   USA
# 74  732402-USA.41_1-1400    53878   732402  USA.41_1  1400   USA
# 72   774160-USA.5_1-1441    58402   774160   USA.5_1  1441   USA
# 71   781002-USA.38_1-725    58589   781002  USA.38_1   725   USA
# 70  732571-USA.10_1-1400    53938   732571  USA.10_1  1400   USA
#
#           country           state     area_km2   bws_raw   bwd_raw   iav_raw  \
# 0   United States        Michigan  2062.767827  0.577778  0.124035  0.322604
# 74  United States  South Carolina  1981.427932  0.671913  0.149271  0.474361
# 72  United States      California  6489.297197  5.307029  1.558770  0.723832
# 71  United States          Oregon  9329.110744  0.063482  0.030697  0.387921
# 70  United States         Florida  9542.228009  0.694238  0.285035  0.581573
#
#      sev_raw   gtd_raw   rfr_raw   drr_raw    cep_raw   udw_raw   usa_raw  \
# 0   0.319555 -0.430512  0.001230  0.404088   1.850749  0.020419  0.000733
# 74  0.170584  0.602974  0.000790  0.367905  -0.261415  0.024722  0.000881
# 72  0.501935 -0.365303  0.000961  0.366932   3.497037  0.005112  0.000205
# 71  0.501520 -0.027497  0.001441  0.294180 -18.101568  0.019064  0.000686
# 70  0.441926  0.602974  0.007218  0.315998  -9.788635  0.005696  0.000225
#
#     presence_absence
# 0                  1
# 74                 1
# 72                 1
# 71                 1
# 70                 1

# %%
summary_statistics = merged_data.describe()
summary_statistics
# Out:
#             aq30_id        pfaf_id         aqid      area_km2      bws_raw  \
# count   2691.000000    2691.000000  2691.000000   2691.000000  2691.000000
# mean   56579.101821  750507.662579   287.048681   3041.224817   141.624147
# std     2837.857596   96796.211884  3013.587416   4496.079277  2434.481907
# min    29004.000000   -9999.000000 -9999.000000      0.004343 -9999.000000
# 25%    54326.500000  742412.000000   740.000000    209.589047     0.002912
# 50%    55294.000000  751910.000000  1216.000000   1338.879402     0.109437
# 75%    58680.500000  782300.000000  1400.000000   4078.623483     0.523438
# max    68401.000000  821004.000000  1793.000000  43544.560066  9999.000000
#
#            bwd_raw      iav_raw      sev_raw      gtd_raw      rfr_raw  \
# count  2691.000000  2691.000000  2691.000000  2691.000000  2691.000000
# mean    141.434259  -226.093788  -226.242596  -813.448132  -144.910443
# std    2434.492792  1488.646194  1488.623515  2734.537102  1195.205980
# min   -9999.000000 -9999.000000 -9999.000000 -9999.000000 -9999.000000
# 25%       0.000774     0.389728     0.251298    -0.274031     0.000211
# 50%       0.033225     0.531438     0.378129     0.001182     0.000952
# 75%       0.178233     0.698350     0.542522     0.363141     0.002829
# max    9999.000000     5.239926     1.596155    10.717500     0.038593
#
#            drr_raw      cep_raw      udw_raw      usa_raw  presence_absence
# count  2691.000000  2691.000000  2691.000000  2691.000000       2691.000000
# mean   -620.197991  -165.234100  -144.889200  -144.910592          0.036418
# std    2412.912857  1268.115283  1195.208557  1195.205962          0.187362
# min   -9999.000000 -9999.000000 -9999.000000 -9999.000000          0.000000
# 25%       0.273718    -1.506533     0.016803     0.000679          0.000000
# 50%       0.357834    -0.119384     0.028248     0.001053          0.000000
# 75%       0.421900     0.934831     0.033246     0.001175          0.000000
# max       0.596387    26.891595     0.081809     0.239945          1.000000

# %%
# Replace -9999 and 9999 values with 0
merged_data_final = merged_data.copy()
merged_data_final.replace(-9999, 0, inplace=True)
merged_data_final.replace(9999, 0, inplace=True)

# %%
summary_statistics = merged_data_final.describe()
summary_statistics
# Out:
#             aq30_id        pfaf_id         aqid      area_km2      bws_raw  \
# count   2691.000000    2691.000000  2691.000000   2691.000000  2691.000000
# mean   56579.101821  750652.575622  1067.349684   3041.224817     0.426823
# std     2837.857596   95657.924622   468.345644   4496.079277     0.984107
# min    29004.000000       0.000000     0.000000      0.004343     0.000000
# 25%    54326.500000  742412.000000   740.000000    209.589047     0.001552
# 50%    55294.000000  751910.000000  1216.000000   1338.879402     0.079560
# 75%    58680.500000  782300.000000  1400.000000   4078.623483     0.389725
# max    68401.000000  821004.000000  1793.000000  43544.560066    11.955757
#
#            bwd_raw      iav_raw      sev_raw      gtd_raw      rfr_raw  \
# count  2691.000000  2691.000000  2691.000000  2691.000000  2691.000000
# mean      0.236935     0.565075     0.416267     0.294343     0.002601
# std       0.568800     0.304964     0.227540     1.075662     0.004343
# min       0.000000     0.000000     0.000000    -2.875680     0.000000
# 25%       0.000427     0.389728     0.251298    -0.159729     0.000211
# 50%       0.023149     0.531438     0.378129     0.001182     0.000952
# 75%       0.137545     0.698350     0.542522     0.363141     0.002829
# max       6.397558     5.239926     1.596155    10.717500     0.038593
#
#            drr_raw      cep_raw      udw_raw      usa_raw  presence_absence
# count  2691.000000  2691.000000  2691.000000  2691.000000       2691.000000
# mean      0.327093    -1.742461     0.023844     0.002452          0.036418
# std       0.145308     8.073369     0.011300     0.010514          0.187362
# min       0.000000   -93.297860     0.000000     0.000000          0.000000
# 25%       0.273718    -1.439017     0.016803     0.000679          0.000000
# 50%       0.357834    -0.119384     0.028248     0.001053          0.000000
# 75%       0.421900     0.934831     0.033246     0.001175          0.000000
# max       0.596387    26.891595     0.081809     0.239945          1.000000

# %%
# Define the columns of interest
columns_of_interest = [col for col in merged_data.columns if '_raw' in col] 

# Calculate the percentage of rows that are zero for each specified column
zero_counts_percentage = {col: (merged_data_final[col] == 0).mean() * 100 for col in columns_of_interest}
zero_counts_percentage
# Out:
# {'bws_raw': 6.986250464511334,
#  'bwd_raw': 7.023411371237458,
#  'iav_raw': 2.266815310293571,
#  'sev_raw': 2.266815310293571,
#  'gtd_raw': 8.65849126718692,
#  'rfr_raw': 12.411742846525456,
#  'drr_raw': 6.205871423262728,
#  'cep_raw': 1.7837235228539576,
#  'udw_raw': 10.070605722779636,
#  'usa_raw': 10.070605722779636}

# %%
# Save the updated merged DataFrame
merged_data_final.to_csv('../data/merged_data.csv', index=False)

# %% [markdown]
# ### Big data

# %%
import pandas as pd

# Load the dataset
big_data = pd.read_csv('./data/attempt2/big_data.csv')

# Filter rows where the 'name_0' column is 'United States'
us_data = big_data[big_data['name_0'] == 'United States']

# Display the filtered DataFrame
print(us_data.shape)
us_data.head()
# Out:
# (3433, 231)
#                  string_id  aq30_id  pfaf_id    gid_1  aqid gid_0  \
# 29007  355000-USA.2_1-1047    29004   355000  USA.2_1  1047   USA
# 29008  355000-USA.2_1-1064    29005   355000  USA.2_1  1064   USA
# 29009  355000-USA.2_1-1079    29006   355000  USA.2_1  1079   USA
# 29010  355000-USA.2_1-1083    29007   355000  USA.2_1  1083   USA
# 29011  355000-USA.2_1-1085    29008   355000  USA.2_1  1085   USA
#
#               name_0  name_1    area_km2   bws_raw  ...  w_awr_tex_qal_label  \
# 29007  United States  Alaska  781.766461  0.000023  ...            Low (0-1)
# 29008  United States  Alaska  206.480664  0.000023  ...            Low (0-1)
# 29009  United States  Alaska  254.894601  0.000023  ...            Low (0-1)
# 29010  United States  Alaska  216.348231  0.000023  ...            Low (0-1)
# 29011  United States  Alaska   60.852730  0.000023  ...            Low (0-1)
#
#        w_awr_tex_rrr_raw w_awr_tex_rrr_score  w_awr_tex_rrr_cat  \
# 29007           2.183257            2.558632                2.0
# 29008           2.183257            2.558632                2.0
# 29009           2.183257            2.558632                2.0
# 29010           2.183257            2.558632                2.0
# 29011           2.183257            2.558632                2.0
#
#        w_awr_tex_rrr_label  w_awr_tex_tot_raw w_awr_tex_tot_score  \
# 29007  Medium - High (2-3)           1.052511            1.070852
# 29008  Medium - High (2-3)           1.052511            1.070852
# 29009  Medium - High (2-3)           1.052511            1.070852
# 29010  Medium - High (2-3)           1.052511            1.070852
# 29011  Medium - High (2-3)           1.052511            1.070852
#
#        w_awr_tex_tot_cat  w_awr_tex_tot_label  w_awr_tex_tot_weight_fraction
# 29007                1.0   Low - Medium (1-2)                       0.877551
# 29008                1.0   Low - Medium (1-2)                       0.877551
# 29009                1.0   Low - Medium (1-2)                       0.877551
# 29010                1.0   Low - Medium (1-2)                       0.877551
# 29011                1.0   Low - Medium (1-2)                       0.877551
#
# [5 rows x 231 columns]

# %%
# Columns to keep are only those with '_raw' in their names (indicating raw values) and essential identifiers
columns_to_keep = ['string_id', 'aq30_id', 'pfaf_id', 'gid_1', 'aqid', 'gid_0', 'name_0', 'name_1', 'area_km2'] + [col for col in us_data.columns if '_raw' in col] 

# Remove all columns starting with 'w_awr' from the columns to keep
columns_to_keep = [col for col in columns_to_keep if not col.startswith('w_awr')]

# Create a new DataFrame with only the columns we want to keep
cleaned_us_data = us_data[columns_to_keep]

# Display the first few rows of the cleaned DataFrame to verify
print(cleaned_us_data.shape)
cleaned_us_data.head(5)
# Out:
# (3433, 22)
#                  string_id  aq30_id  pfaf_id    gid_1  aqid gid_0  \
# 29007  355000-USA.2_1-1047    29004   355000  USA.2_1  1047   USA
# 29008  355000-USA.2_1-1064    29005   355000  USA.2_1  1064   USA
# 29009  355000-USA.2_1-1079    29006   355000  USA.2_1  1079   USA
# 29010  355000-USA.2_1-1083    29007   355000  USA.2_1  1083   USA
# 29011  355000-USA.2_1-1085    29008   355000  USA.2_1  1085   USA
#
#               name_0  name_1    area_km2   bws_raw  ...  sev_raw  gtd_raw  \
# 29007  United States  Alaska  781.766461  0.000023  ...  0.12846  -9999.0
# 29008  United States  Alaska  206.480664  0.000023  ...  0.12846  -9999.0
# 29009  United States  Alaska  254.894601  0.000023  ...  0.12846  -9999.0
# 29010  United States  Alaska  216.348231  0.000023  ...  0.12846  -9999.0
# 29011  United States  Alaska   60.852730  0.000023  ...  0.12846  -9999.0
#
#         rfr_raw  cfr_raw   drr_raw   ucw_raw  cep_raw   udw_raw   usa_raw  \
# 29007  0.000106      0.0  0.084501  0.264205  -9999.0  0.081809  0.239945
# 29008  0.000106      0.0  0.084501  0.264205  -9999.0  0.081809  0.239945
# 29009  0.000106      0.0  0.084501  0.264205  -9999.0  0.081809  0.239945
# 29010  0.000106      0.0  0.084501  0.264205  -9999.0  0.081809  0.239945
# 29011  0.000106      0.0  0.084501  0.264205  -9999.0  0.081809  0.239945
#
#        rri_raw
# 29007     22.0
# 29008     22.0
# 29009     22.0
# 29010     22.0
# 29011     22.0
#
# [5 rows x 22 columns]

# %%
# Create a copy of the DataFrame to avoid SettingWithCopyWarning
cleaned_us_data = us_data[columns_to_keep].copy()

# Rename the columns 'name_0' to 'country' and 'name_1' to 'state'
cleaned_us_data.rename(columns={'name_0': 'country', 'name_1': 'state'}, inplace=True)

# Display the first few rows of the DataFrame to verify the new column names
cleaned_us_data.head(3)
# Out:
#                  string_id  aq30_id  pfaf_id    gid_1  aqid gid_0  \
# 29007  355000-USA.2_1-1047    29004   355000  USA.2_1  1047   USA
# 29008  355000-USA.2_1-1064    29005   355000  USA.2_1  1064   USA
# 29009  355000-USA.2_1-1079    29006   355000  USA.2_1  1079   USA
#
#              country   state    area_km2   bws_raw  ...  sev_raw  gtd_raw  \
# 29007  United States  Alaska  781.766461  0.000023  ...  0.12846  -9999.0
# 29008  United States  Alaska  206.480664  0.000023  ...  0.12846  -9999.0
# 29009  United States  Alaska  254.894601  0.000023  ...  0.12846  -9999.0
#
#         rfr_raw  cfr_raw   drr_raw   ucw_raw  cep_raw   udw_raw   usa_raw  \
# 29007  0.000106      0.0  0.084501  0.264205  -9999.0  0.081809  0.239945
# 29008  0.000106      0.0  0.084501  0.264205  -9999.0  0.081809  0.239945
# 29009  0.000106      0.0  0.084501  0.264205  -9999.0  0.081809  0.239945
#
#        rri_raw
# 29007     22.0
# 29008     22.0
# 29009     22.0
#
# [3 rows x 22 columns]

# %% [markdown]
# ### Small data

# %%
import pandas as pd

# Load the dataset
small_data = pd.read_csv('./data/attempt2/small_data.csv')

# Display the filtered DataFrame
print(small_data.shape)
small_data.head()
# Out:
# (360, 271)
#                                             the_geom  points_id location_name  \
# 0  0101000020E610000070253B3602EF54C01B649291B322...          0     undefined
# 1  0101000020E61000008811C2A38DC951C0FFEC478AC83C...          1     undefined
# 2  0101000020E6100000E4C8FB1FFD5353C0DC7D12C83A76...          2     undefined
# 3  0101000020E610000093BC001C77A352C04961621CF123...          3     undefined
# 4  0101000020E6100000CAA5F10BAF7B5EC0D7CF8BA8C3BE...          4     undefined
#
#   input_address match_address   latitude   longitude  \
# 0             _             -  42.271105  -83.734510
# 1             _             -  42.474870  -71.149270
# 2             _             -  42.923669  -77.312325
# 3             _             -  40.280796  -74.554145
# 4             _             -  37.490346 -121.932559
#
#                       major_basin_name minor_basin_name aquifer_name  ...  \
# 0                          St Lawrence            Huron          NaN  ...
# 1              Atlantic Ocean Seaboard          Charles          NaN  ...
# 2                          St Lawrence           Seneca          NaN  ...
# 3  United States, North Atlantic Coast          Raritan          NaN  ...
# 4                           California           Coyote          NaN  ...
#
#   w_awr_tex_rrr_raw  w_awr_tex_rrr_score  w_awr_tex_rrr_cat  \
# 0          0.617001             1.290826                  1
# 1          0.461973             1.148599                  1
# 2          0.694777             1.362180                  1
# 3          0.486630             1.171221                  1
# 4          0.440000             1.128440                  1
#
#   w_awr_tex_rrr_label  w_awr_tex_rrr_weight_fraction w_awr_tex_tot_raw  \
# 0  Low - Medium (1-2)                       0.326531          1.168445
# 1  Low - Medium (1-2)                       0.326531          1.101490
# 2  Low - Medium (1-2)                       0.326531          0.760882
# 3  Low - Medium (1-2)                       0.326531          1.191432
# 4  Low - Medium (1-2)                       0.326531          1.265384
#
#   w_awr_tex_tot_score w_awr_tex_tot_cat  w_awr_tex_tot_label  \
# 0            1.264075                 1   Low - Medium (1-2)
# 1            1.152484                 1   Low - Medium (1-2)
# 2            0.753348                 0            Low (0-1)
# 3            1.302387                 1   Low - Medium (1-2)
# 4            1.425640                 1   Low - Medium (1-2)
#
#    w_awr_tex_tot_weight_fraction
# 0                       0.918367
# 1                       0.918367
# 2                       0.918367
# 3                       1.000000
# 4                       0.918367
#
# [5 rows x 271 columns]

# %%
# Define the columns to keep
columns_to_keep = ['string_id', 'aq30_id', 'pfaf_id', 'gid_1', 'aqid', 'gid_0', 'name_0', 'name_1', 'area_km2'] + [col for col in small_data.columns if '_raw' in col]

# Remove any columns starting with 'w_awr' from the list
columns_to_keep = [col for col in columns_to_keep if not col.startswith('w_awr')]

# Create a new DataFrame with only the specified columns
cleaned_small_data = small_data[columns_to_keep].copy()

# %%
# Display the filtered DataFrame
print(cleaned_small_data.shape)
cleaned_small_data.head()
# Out:
# (360, 22)
#               string_id  aq30_id  pfaf_id     gid_1  aqid gid_0  \
# 0   725572-USA.23_1-844    53190   725572  USA.23_1   844   USA
# 1  731190-USA.22_1-1158    53593   731190  USA.22_1  1158   USA
# 2  725540-USA.33_1-1158    53139   725540  USA.33_1  1158   USA
# 3  731504-USA.31_1-1400    53662   731504  USA.31_1  1400   USA
# 4   774300-USA.5_1-1441    58425   774300   USA.5_1  1441   USA
#
#           name_0         name_1      area_km2   bws_raw  ...   sev_raw  \
# 0  United States       Michigan   2062.767827  0.577778  ...  0.319555
# 1  United States  Massachusetts   8235.727113  0.227893  ...  0.062591
# 2  United States       New York  13679.987580  0.001699  ...  0.388458
# 3  United States     New Jersey   1133.681346  0.733216  ...  0.301855
# 4  United States     California  10534.359930  0.168964  ...  0.713420
#
#     gtd_raw   rfr_raw   cfr_raw   drr_raw   ucw_raw   cep_raw   udw_raw  \
# 0 -0.430512  0.001230  0.000000  0.404088  0.264205  1.850749  0.020419
# 1 -0.888467  0.003236  0.000043  0.283779  0.264205  5.962378  0.013285
# 2 -0.888467  0.001266  0.000000  0.333397  0.264205  1.928940  0.025333
# 3  0.602974  0.000191  0.000000  0.344127  0.264205  7.842522  0.014225
# 4 -0.365303  0.007320  0.000049  0.363087  0.264205  9.124589  0.005542
#
#     usa_raw  rri_raw
# 0  0.000733       22
# 1  0.000486       22
# 2  0.000902       22
# 3  0.000519       22
# 4  0.000220       22
#
# [5 rows x 22 columns]

# %%
# Rename the columns 'name_0' to 'country' and 'name_1' to 'state'
cleaned_small_data.rename(columns={'name_0': 'country', 'name_1': 'state'}, inplace=True)

# %%
cleaned_small_data.head(3)
# Out:
#               string_id  aq30_id  pfaf_id     gid_1  aqid gid_0  \
# 0   725572-USA.23_1-844    53190   725572  USA.23_1   844   USA
# 1  731190-USA.22_1-1158    53593   731190  USA.22_1  1158   USA
# 2  725540-USA.33_1-1158    53139   725540  USA.33_1  1158   USA
#
#          country          state      area_km2   bws_raw  ...   sev_raw  \
# 0  United States       Michigan   2062.767827  0.577778  ...  0.319555
# 1  United States  Massachusetts   8235.727113  0.227893  ...  0.062591
# 2  United States       New York  13679.987580  0.001699  ...  0.388458
#
#     gtd_raw   rfr_raw   cfr_raw   drr_raw   ucw_raw   cep_raw   udw_raw  \
# 0 -0.430512  0.001230  0.000000  0.404088  0.264205  1.850749  0.020419
# 1 -0.888467  0.003236  0.000043  0.283779  0.264205  5.962378  0.013285
# 2 -0.888467  0.001266  0.000000  0.333397  0.264205  1.928940  0.025333
#
#     usa_raw  rri_raw
# 0  0.000733       22
# 1  0.000486       22
# 2  0.000902       22
#
# [3 rows x 22 columns]

# %% [markdown]
# ### Saving both dataframe in CSV files

# %%
# Save the cleaned large dataset to a CSV file
cleaned_us_data.to_csv('./data/attempt2/cleaned_large_data.csv', index=False)

# Save the cleaned small dataset to a CSV file
cleaned_small_data.to_csv('./data/attempt2/cleaned_small_data.csv', index=False)

# %% [markdown]
# ### Load the saved files again and Look for duplicate values

# %%
import pandas as pd

# Assuming you have already loaded your datasets into DataFrame
# Load datasets if not already done
large_data = pd.read_csv('./data/attempt2/cleaned_large_data.csv')
small_data = pd.read_csv('./data/attempt2/cleaned_small_data.csv')

# Remove duplicates based on 'aqid' and all other columns
small_data = small_data.drop_duplicates(subset=['aqid'] + list(small_data.columns))
large_data = large_data.drop_duplicates(subset=['aqid'] + list(large_data.columns))

# Save the cleaned datasets
small_data.to_csv('cleaned_small_data.csv', index=False)
large_data.to_csv('cleaned_large_data.csv', index=False)

# %%
large_data
# Out:
#                 string_id  aq30_id  pfaf_id    gid_1  aqid gid_0  \
# 0     355000-USA.2_1-1047    29004   355000  USA.2_1  1047   USA
# 1     355000-USA.2_1-1064    29005   355000  USA.2_1  1064   USA
# 2     355000-USA.2_1-1079    29006   355000  USA.2_1  1079   USA
# 3     355000-USA.2_1-1083    29007   355000  USA.2_1  1083   USA
# 4     355000-USA.2_1-1085    29008   355000  USA.2_1  1085   USA
# ...                   ...      ...      ...      ...   ...   ...
# 3428    None-USA.5_1-None    68403    -9999  USA.5_1 -9999   USA
# 3429    None-USA.7_1-1158    68404    -9999  USA.7_1  1158   USA
# 3430    None-USA.7_1-None    68405    -9999  USA.7_1 -9999   USA
# 3431    None-USA.8_1-1400    68406    -9999  USA.8_1  1400   USA
# 3432    None-USA.8_1-None    68407    -9999  USA.8_1 -9999   USA
#
#             country        state    area_km2      bws_raw  ...     sev_raw  \
# 0     United States       Alaska  781.766461     0.000023  ...     0.12846
# 1     United States       Alaska  206.480664     0.000023  ...     0.12846
# 2     United States       Alaska  254.894601     0.000023  ...     0.12846
# 3     United States       Alaska  216.348231     0.000023  ...     0.12846
# 4     United States       Alaska   60.852730     0.000023  ...     0.12846
# ...             ...          ...         ...          ...  ...         ...
# 3428  United States   California    2.810765 -9999.000000  ... -9999.00000
# 3429  United States  Connecticut    0.095773 -9999.000000  ... -9999.00000
# 3430  United States  Connecticut    0.021823 -9999.000000  ... -9999.00000
# 3431  United States     Delaware   40.415160 -9999.000000  ... -9999.00000
# 3432  United States     Delaware   75.628511 -9999.000000  ... -9999.00000
#
#           gtd_raw      rfr_raw  cfr_raw      drr_raw   ucw_raw  cep_raw  \
# 0    -9999.000000     0.000106      0.0     0.084501  0.264205  -9999.0
# 1    -9999.000000     0.000106      0.0     0.084501  0.264205  -9999.0
# 2    -9999.000000     0.000106      0.0     0.084501  0.264205  -9999.0
# 3    -9999.000000     0.000106      0.0     0.084501  0.264205  -9999.0
# 4    -9999.000000     0.000106      0.0     0.084501  0.264205  -9999.0
# ...           ...          ...      ...          ...       ...      ...
# 3428 -9999.000000 -9999.000000  -9999.0 -9999.000000  0.264205  -9999.0
# 3429    -0.888467 -9999.000000  -9999.0 -9999.000000  0.264205  -9999.0
# 3430 -9999.000000 -9999.000000  -9999.0 -9999.000000  0.264205  -9999.0
# 3431     0.602974 -9999.000000  -9999.0 -9999.000000  0.264205  -9999.0
# 3432 -9999.000000 -9999.000000  -9999.0 -9999.000000  0.264205  -9999.0
#
#           udw_raw      usa_raw  rri_raw
# 0        0.081809     0.239945     22.0
# 1        0.081809     0.239945     22.0
# 2        0.081809     0.239945     22.0
# 3        0.081809     0.239945     22.0
# 4        0.081809     0.239945     22.0
# ...           ...          ...      ...
# 3428 -9999.000000 -9999.000000     22.0
# 3429 -9999.000000 -9999.000000     22.0
# 3430 -9999.000000 -9999.000000     22.0
# 3431 -9999.000000 -9999.000000     22.0
# 3432 -9999.000000 -9999.000000     22.0
#
# [3433 rows x 22 columns]

# %%
small_data
# Out:
#                 string_id  aq30_id  pfaf_id     gid_1  aqid gid_0  \
# 0     725572-USA.23_1-844    53190   725572  USA.23_1   844   USA
# 1    731190-USA.22_1-1158    53593   731190  USA.22_1  1158   USA
# 2    725540-USA.33_1-1158    53139   725540  USA.33_1  1158   USA
# 3    731504-USA.31_1-1400    53662   731504  USA.31_1  1400   USA
# 4     774300-USA.5_1-1441    58425   774300   USA.5_1  1441   USA
# ..                    ...      ...      ...       ...   ...   ...
# 346  742493-USA.17_1-1363    54397   742493  USA.17_1  1363   USA
# 351  725555-USA.33_1-1158    53156   725555  USA.33_1  1158   USA
# 352  742678-USA.36_1-1216    54575   742678  USA.36_1  1216   USA
# 354  732407-USA.41_1-1414    53888   732407  USA.41_1  1414   USA
# 355  751640-USA.44_1-1612    55189   751640  USA.44_1  1612   USA
#
#            country           state      area_km2   bws_raw  ...   sev_raw  \
# 0    United States        Michigan   2062.767827  0.577778  ...  0.319555
# 1    United States   Massachusetts   8235.727113  0.227893  ...  0.062591
# 2    United States        New York  13679.987580  0.001699  ...  0.388458
# 3    United States      New Jersey   1133.681346  0.733216  ...  0.301855
# 4    United States      California  10534.359930  0.168964  ...  0.713420
# ..             ...             ...           ...       ...  ...       ...
# 346  United States          Kansas  14058.932370  0.304765  ...  0.456868
# 351  United States        New York   5746.506270  0.005066  ...  0.328150
# 352  United States            Ohio  17080.695270  0.356605  ...  0.207962
# 354  United States  South Carolina    514.146944  0.152156  ...  0.096399
# 355  United States           Texas  13176.612830  0.245373  ...  0.167992
#
#       gtd_raw   rfr_raw   cfr_raw   drr_raw   ucw_raw   cep_raw   udw_raw  \
# 0   -0.430512  0.001230  0.000000  0.404088  0.264205  1.850749  0.020419
# 1   -0.888467  0.003236  0.000043  0.283779  0.264205  5.962378  0.013285
# 2   -0.888467  0.001266  0.000000  0.333397  0.264205  1.928940  0.025333
# 3    0.602974  0.000191  0.000000  0.344127  0.264205  7.842522  0.014225
# 4   -0.365303  0.007320  0.000049  0.363087  0.264205  9.124589  0.005542
# ..        ...       ...       ...       ...       ...       ...       ...
# 346  0.328266  0.002351  0.000000  0.530588  0.264205  0.934831  0.017656
# 351 -0.888467  0.001880  0.000000  0.315653  0.264205  1.718303  0.013828
# 352 -0.274031  0.000126  0.000000  0.501858  0.264205  0.934937  0.015105
# 354  1.070200  0.000015  0.000000  0.376405  0.264205 -0.320061  0.025970
# 355  0.707641  0.001437  0.000000  0.455871  0.264205 -0.527336  0.017909
#
#       usa_raw  rri_raw
# 0    0.000733       22
# 1    0.000486       22
# 2    0.000902       22
# 3    0.000519       22
# 4    0.000220       22
# ..        ...      ...
# 346  0.000637       22
# 351  0.001975       22
# 352  0.000550       22
# 354  0.000924       22
# 355  0.000646       22
#
# [98 rows x 22 columns]

# %%
# Ensuring both dataframes have the same columns and in the same order
small_data = small_data.reindex(columns=large_data.columns)

# %%
# Concatenate the DataFrames
merged_data = pd.concat([small_data, large_data], ignore_index=True)

# %%
merged_data.shape
# Out:
# (3531, 22)

# %%
# Adding a 'presence_absence' column
# Assuming 'small_data' has been assigned 1 (With) and 'big_data' 0 (Without)
merged_data['presence_absence'] = [1] * len(small_data) + [0] * len(large_data)

# %%
# Sort the merged data by 'presence_absence' in descending order so that '1' (with) comes before '0' (without)
merged_data.sort_values(by='presence_absence', ascending=False, inplace=True)

# %%
merged_data
# Out:
#                  string_id  aq30_id  pfaf_id     gid_1  aqid gid_0  \
# 0      725572-USA.23_1-844    53190   725572  USA.23_1   844   USA
# 74    732402-USA.41_1-1400    53878   732402  USA.41_1  1400   USA
# 72     774160-USA.5_1-1441    58402   774160   USA.5_1  1441   USA
# 71     781002-USA.38_1-725    58589   781002  USA.38_1   725   USA
# 70    732571-USA.10_1-1400    53938   732571  USA.10_1  1400   USA
# ...                    ...      ...      ...       ...   ...   ...
# 1244  742677-USA.36_1-1397    54574   742677  USA.36_1  1397   USA
# 1245  742678-USA.36_1-1216    54575   742678  USA.36_1  1216   USA
# 1246  742679-USA.18_1-1216    54576   742679  USA.18_1  1216   USA
# 1247  742679-USA.36_1-1216    54577   742679  USA.36_1  1216   USA
# 3530     None-USA.8_1-None    68407    -9999   USA.8_1 -9999   USA
#
#             country           state      area_km2      bws_raw  ...  \
# 0     United States        Michigan   2062.767827     0.577778  ...
# 74    United States  South Carolina   1981.427932     0.671913  ...
# 72    United States      California   6489.297197     5.307029  ...
# 71    United States          Oregon   9329.110744     0.063482  ...
# 70    United States         Florida   9542.228009     0.694238  ...
# ...             ...             ...           ...          ...  ...
# 1244  United States            Ohio   5214.477446     0.031141  ...
# 1245  United States            Ohio  17080.695272     0.356605  ...
# 1246  United States        Kentucky   8962.652611     0.361580  ...
# 1247  United States            Ohio   4649.532625     0.361580  ...
# 3530  United States        Delaware     75.628511 -9999.000000  ...
#
#           gtd_raw      rfr_raw      cfr_raw      drr_raw   ucw_raw  \
# 0       -0.430512     0.001230     0.000000     0.404088  0.264205
# 74       0.602974     0.000790     0.000000     0.367905  0.264205
# 72      -0.365303     0.000961     0.000000     0.366932  0.264205
# 71      -0.027497     0.001441     0.000000     0.294180  0.264205
# 70       0.602974     0.007218     0.000013     0.315998  0.264205
# ...           ...          ...          ...          ...       ...
# 1244     0.425349     0.000638     0.000000     0.482472  0.264205
# 1245    -0.274031     0.000126     0.000000     0.501858  0.264205
# 1246    -0.274031     0.002577     0.000000     0.403591  0.264205
# 1247    -0.274031     0.002577     0.000000     0.403591  0.264205
# 3530 -9999.000000 -9999.000000 -9999.000000 -9999.000000  0.264205
#
#           cep_raw      udw_raw      usa_raw  rri_raw  presence_absence
# 0        1.850749     0.020419     0.000733     22.0                 1
# 74      -0.261415     0.024722     0.000881     22.0                 1
# 72       3.497037     0.005112     0.000205     22.0                 1
# 71     -18.101568     0.019064     0.000686     22.0                 1
# 70      -9.788635     0.005696     0.000225     22.0                 1
# ...           ...          ...          ...      ...               ...
# 1244     0.934831     0.019269     0.000693     22.0                 0
# 1245     0.934937     0.015105     0.000550     22.0                 0
# 1246     0.934831     0.030692     0.001087     22.0                 0
# 1247     0.934831     0.030692     0.001087     22.0                 0
# 3530 -9999.000000 -9999.000000 -9999.000000     22.0                 0
#
# [3531 rows x 23 columns]

# %%
# Drop duplicates based on all columns except 'presence_absence'
merged_data.drop_duplicates(subset=merged_data.columns.difference(['presence_absence']), keep='first', inplace=True)

# %%
# Save the updated merged DataFrame
merged_data.to_csv('./data/attempt2/merged_data.csv', index=False)
